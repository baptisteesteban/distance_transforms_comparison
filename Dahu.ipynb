# %%
import numpy as np
from imageio.v3 import imread
import matplotlib.pyplot as plt

from dahu import *

# %%
img = imread("/home/baptou/Pictures/ecssd/gray_png/0001.png")

# %%
m, M = immersion(img)

# %%
plt.figure(figsize=(13, 8))
plt.subplot(131)
plt.imshow(img, cmap="gray")
plt.subplot(132)
plt.imshow(m, cmap="gray")
plt.subplot(133)
plt.imshow(M, cmap="gray")
plt.show()

# %%
def dahu_distance_map(m: np.ndarray, M: np.ndarray, seeds: np.ndarray) -> np.ndarray:
    pass
